# %%
from dm_control.rl import environment

# %%
import matplotlib.pyplot as plt

# %%
from dm_control import suite

# %%
import numpy as np

# %%
np.clip(np.random.randn(1),-1.0,1.0)
# Out:
# array([0.8752618])

# %%
env = suite.load(domain_name='cartpole', task_name="swingup")

# %%
env.action_spec()
# Out:
# BoundedArraySpec(shape=(1,), dtype=dtype('float64'), name=None, minimum=[-1.], maximum=[1.])

# %%
env.step([1])
# Out:
# TimeStep(step_type=<StepType.MID: 1>, reward=0.01684062959033189, discount=1.0, observation=OrderedDict([('position', array([ 0.25349982, -0.94213633, -0.33522998])), ('velocity', array([2.20345488, 2.81448339]))]))

# %%
env.reset()
# Out:
# TimeStep(step_type=<StepType.FIRST: 0>, reward=None, discount=None, observation=OrderedDict([('position', array([-7.00973561e-04, -9.99974151e-01,  7.19002354e-03])), ('velocity', array([-0.00878629, -0.02022116]))]))

# %%
plt.imshow(env.physics.render())b

# %%
env.physics.render()
# Out:
# (240, 320, 3)
